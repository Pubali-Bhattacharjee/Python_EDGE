# %%
import re


text = "My birthday is on 12/05/2023 and I have an appointment on 22/11/2024."

date_pattern = r"\b\d{2}/\d{2}/\d{4}\b"

dates = re.findall(date_pattern, text)

print(dates)
# Out:
# ['12/05/2023', '22/11/2024']
